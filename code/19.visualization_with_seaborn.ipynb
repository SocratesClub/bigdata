# %%
# %matplotlib inline

import numpy as np; np.random.seed(22)
import seaborn as sns; 
sns.set(color_codes=True)

x = np.linspace(0, 15, 15)
data = np.sin(x) + np.random.rand(10, 15) + np.random.randn(10, 1)
ax = sns.tsplot(data=data)
# Out:
# /Users/datalab/Applications/anaconda/lib/python3.5/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
data
# Out:
# array([[ 0.6726167 ,  1.42526277,  1.72616519,  2.32083315,  1.54461515,
#          1.40149227,  0.87580901,  0.80441429, -0.07224181,  0.29857697,
#         -0.48424123,  0.31981954,  0.99846686,  1.42437645,  1.31025412,
#          1.40829701,  2.22555828,  2.22047545,  1.57821254,  0.68658331,
#          0.6881278 ,  0.27267873, -0.14865056,  0.20390982,  0.35513849,
#          0.98212391,  1.58695872,  1.37983576,  2.37803345,  2.3879375 ,
#          1.79185478],
#        [-0.43621914, -0.72288203, -0.21215386,  0.64103881,  0.42284559,
#         -0.12482161, -0.96193001, -1.09788291, -1.47241293, -1.89764937,
#         -2.14464665, -1.49924358, -1.41491481, -0.97105382,  0.1104314 ,
#          0.5558068 , -0.11681849, -0.3038328 , -0.34620543, -1.10897653,
#         -0.99378228, -1.50366581, -1.78787403, -1.12480698, -1.05900142,
#         -1.0789754 , -0.64372858,  0.11116598,  0.07264423,  0.61504814,
#         -0.4948404 ],
#        [-1.15693699, -0.77244812,  0.10712619,  0.35502433,  0.18285087,
#         -0.69500184, -0.47143782, -1.81628184, -1.87017035, -1.49539289,
#         -1.48815891, -2.15350233, -1.07741052, -1.0917767 , -0.24589205,
#         -0.29088809, -0.32379686, -0.16896109, -0.48709739, -1.07620973,
#         -1.50686489, -2.02695517, -1.58450287, -2.09462768, -1.14549613,
#         -0.90213673, -0.3536208 , -0.636773  ,  0.17690764,  0.46320646,
#         -0.3141777 ],
#        [ 1.25380463,  1.24138729,  1.36265852,  2.12250743,  2.03812837,
#          0.9775839 ,  1.25258492,  0.42041733,  0.41556718, -0.29395437,
#         -0.43533777,  0.48780799,  0.64445138,  1.36813161,  1.0068781 ,
#          1.96345548,  2.07351304,  1.51558318,  0.92671363,  0.41493084,
#          0.66663361,  0.17240521,  0.20836271, -0.28724893,  0.44840531,
#          0.68982403,  1.25599442,  1.69034134,  1.34628125,  2.12844035,
#          1.32152215],
#        [-0.84609652, -0.89816345, -0.49457141,  0.54579892, -0.26359758,
#         -0.06168502, -0.84582269, -0.99970035, -1.49066269, -1.43749266,
#         -1.72981359, -2.05344609, -1.54883698, -0.41343364, -0.27623244,
#          0.15767716,  0.46806644, -0.08612928, -0.15592946, -0.81101017,
#         -1.47042735, -2.03572856, -1.54874078, -1.75006712, -1.89485388,
#         -1.2967029 , -0.05614918, -0.54595656,  0.07716932, -0.37122121,
#         -0.19485513],
#        [-0.53838073, -0.70212995,  0.54650868,  0.19485874,  0.64734142,
#         -0.25855414, -0.5139151 , -1.30725201, -1.81140672, -1.69939543,
#         -1.19462958, -1.43073257, -1.17288844, -0.83052925, -0.53301551,
#          0.25857166,  0.2395146 ,  0.42424807, -0.41349669, -1.04744752,
#         -0.77941367, -1.31466412, -2.17077125, -1.79316715, -1.68731229,
#         -0.55432485, -0.56025323, -0.07883656,  0.41328362,  0.53601282,
#          0.13839468],
#        [ 0.23229141,  1.08228128,  1.05600827,  1.48742917,  0.91770588,
#          1.27248518,  0.80114066, -0.06003443, -0.70538254, -1.14511358,
#         -0.59191008, -0.36992571, -0.40628147,  0.6107723 ,  1.46427013,
#          1.57202347,  1.40603705,  1.41391492,  1.01592868,  0.19941683,
#         -0.32228602, -0.42298825, -1.07494005, -0.85824756, -0.62460032,
#          0.75777946,  1.05374853,  1.08352002,  0.99758181,  0.76573615,
#          1.15801937],
#        [ 0.03610165,  1.02871206,  0.96814603,  0.7247723 ,  1.14117985,
#          0.2259254 ,  0.24353815,  0.06743878, -0.72757369, -0.91510488,
#         -0.44771336, -0.38857891, -0.12696506, -0.11729812,  0.99414654,
#          0.8724561 ,  1.44012495,  1.00738892,  0.44502326,  0.14066926,
#         -0.81797799, -0.90072781, -0.46746009, -0.74213525, -0.40410056,
#         -0.23328721,  0.62472249,  0.58969376,  1.5430677 ,  0.79848609,
#          0.82322971],
#        [ 1.272267  ,  1.67428346,  2.10571679,  2.08500924,  1.52768777,
#          1.76673356,  1.5941398 ,  0.31618267,  0.56094535, -0.05904032,
#          0.06489984,  0.13607848,  0.79207021,  1.17543317,  1.59665543,
#          1.89809518,  2.21612089,  2.04581354,  1.2798722 ,  0.53176206,
#          0.39540754, -0.14805861,  0.0922169 ,  0.5504571 ,  0.06085842,
#          0.50808191,  1.00334308,  1.68968381,  1.56194559,  1.51686319,
#          1.79781106],
#        [ 2.75843589,  3.02276048,  3.64803647,  3.2642171 ,  3.67946998,
#          3.74785894,  3.17628364,  2.70551084,  1.66156679,  2.19246399,
#          1.62189055,  1.60772731,  1.97773633,  2.89555072,  3.39132847,
#          3.1445841 ,  3.75955263,  3.05460622,  2.76118641,  2.38280821,
#          2.22139674,  2.04374881,  1.87766694,  1.96670548,  2.05080123,
#          2.57914958,  3.18484661,  3.32652216,  4.02001749,  3.91133834,
#          3.13133477]])

# %%
ax = sns.tsplot(data=data, err_style="ci_bars", interpolate=False)
# Out:
# /Users/chengjun/anaconda3/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
ax = sns.tsplot(data=data, ci=[68, 95], color="m")
# Out:
# /Users/chengjun/anaconda3/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
ax = sns.tsplot(data=data, ci="sd")
# Out:
# /Users/chengjun/anaconda3/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
ax = sns.tsplot(data=data, estimator=np.median)
# Out:
# /Users/chengjun/anaconda3/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %%
ax = sns.tsplot(data=data, err_style="boot_traces", n_boot=500)
# Out:
# /Users/chengjun/anaconda3/lib/python3.6/site-packages/seaborn/timeseries.py:183: UserWarning: The tsplot function is deprecated and will be removed or replaced (in a substantially altered version) in a future release.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# http://seaborn.pydata.org/generated/seaborn.barplot.html#seaborn.barplot

# %%
import seaborn as sns; 
sns.set(color_codes=True)
tips = sns.load_dataset("tips")
ax = sns.barplot(x="day", y="total_bill", data=tips)

# %%
ax = sns.barplot(x="day", y="total_bill", hue="sex", data=tips)
