# %%
from scipy.misc import imread, imshow, imresize, imsave
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
img = imread('/Users/chengjun/github/cjc2016/figure/crop/wordcloud-1954.png')
plt.imshow(img)
plt.show()

# %%
img = imresize(img,[400,300])
plt.imshow(img)
plt.show()

# %%
imsave('/Users/chengjun/github/cjc2016/figure/crop/rgb_gradient.png', img)
